# %%
# 1. Add all notebooks at once
git add notebooks/*.ipynb

# 2. Check that all files are staged
git status

# 3. Commit the batch fix
git commit -m "fix: restore all notebooks with correct JSON formatting"

# 4. Push to main
git push origin m""" a """
